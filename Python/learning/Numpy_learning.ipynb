# %%
import numpy as np
import statistics
from matplotlib import pyplot

# %%
matrix_1 = np.random.randint(low=5, high=20, size=(5))
pyplot.plot(matrix_1)

# %%
matrix_1 = np.random.randint(low=5, high=20, size=(5))
matrix_2 = np.random.randint(low=5, high=20, size=(5))
pyplot.bar(matrix_1, matrix_2, alpha=0.3)
# Out:
# <BarContainer object of 5 artists>

# %%
matrix_1 = np.random.randint(low=5, high=20, size=(5))
pyplot.pie(matrix_1, autopct='%1.0f%%')
pyplot.title("SoSaL?")
# Out:
# Text(0.5, 1.0, 'SoSaL?')
