# %%
import pandas as pd

# %%
df = pd.read_csv("data/data.csv", encoding="Windows-1251")

# %%
pd.describe_option() #? Посмотреть все опции доступные для кастомизации вывода

# %%
pd.get_option("display.max_columns") #? возращает текущее знаечение заданной опции
# Out:
# 40

# %%
 #? смена опции на новое значение. Синтаксис(опция, новое_значение)
pd.set_option("display.max_columns", 40) # смена отображаемого количества столбцов при выводе на 40
pd.set_option("display.float_format", "{:.2f}".format) # смена отображения float числа, теперь 2 знака после запятой надо для DR_BCDisc

# %%
df.tail()
# Out:
#           DR_Dat    DR_Tim  DR_NChk   DR_NDoc  DR_Apt  DR_Kkm  \
# 4457  2022-08-12  21:40:17     5690  18002542      18    9907
# 4458  2022-08-12  21:40:59     5691  18002542      18    9907
# 4459  2022-08-12  21:43:48     5692  18002542      18    9907
# 4460  2022-08-12  21:44:46     5693  18002542      18    9907
# 4461  2022-08-12  21:46:08     5694  18002542      18    9907
#
#                                                 DR_TDoc  DR_TPay  DR_CDrugs  \
# 4457  пїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅ пїЅпїЅпїЅпїЅпїЅпїЅ...       18     463100
# 4458  пїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅ пїЅпїЅпїЅпїЅпїЅпїЅ...       18     112158
# 4459  пїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅ пїЅпїЅпїЅпїЅпїЅпїЅ...       18     260990
# 4460  пїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅ пїЅпїЅпїЅпїЅпїЅпїЅ...       18      41512
# 4461  пїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅ пїЅпїЅпїЅпїЅпїЅпїЅ...       15      25673
#
#                                               DR_NDrugs  \
# 4457  пїЅпїЅпїЅпїЅпїЅпїЅпїЅ пїЅпїЅпїЅпїЅпїЅпїЅпїЅпїЅ...
# ...

# %%
df.dtypes # посмотреть типы данных столбцов в DataFrame
# Out:
# DR_Dat         object
# DR_Tim         object
# DR_NChk         int64
# DR_NDoc         int64
# DR_Apt          int64
# DR_Kkm          int64
# DR_TDoc        object
# DR_TPay         int64
# DR_CDrugs       int64
# DR_NDrugs      object
# DR_Suppl       object
# DR_Prod        object
# DR_Kol        float64
# DR_CZak       float64
# DR_CRoz       float64
# DR_SDisc      float64
# DR_CDisc      float64
# DR_BCDisc     float64
# DR_TabEmpl      int64
# DR_VZak         int64
# DR_Pos        float64
# dtype: object
